# %%
import netCDF4 as nc
import numpy as np
import xarray as xr
import pandas as pd

# %%
ds = xarray.open_mfdataset('/content/drive/MyDrive/data/CO2/*.nc', concat_dim=["sounding_dim"], combine="nested")
ds.to_netcdf('/content/drive/MyDrive/data/test/CO2.nc')

# %%
my_nc_file = '/content/drive/MyDrive/data/CO2/20120601-C3S-L2_GHG-GHG_PRODUCTS-MERGED-MERGED-EMMA-DAILY-v4.3.nc'
ds = nc.Dataset(my_nc_file)
for dim in ds.dimensions.values():
    print(dim)
# Out:
# <class 'netCDF4._netCDF4.Dimension'>: name = 'sounding_dim', size = 489
# <class 'netCDF4._netCDF4.Dimension'>: name = 'layer_dim', size = 10
# <class 'netCDF4._netCDF4.Dimension'>: name = 'level_dim', size = 11

# %%
my_nc_file = '/content/drive/MyDrive/data/CO2/20120601-C3S-L2_GHG-GHG_PRODUCTS-MERGED-MERGED-EMMA-DAILY-v4.3.nc'
ds = xr.open_mfdataset(my_nc_file)
m_data = ds.to_dataframe().reset_index(drop=True)
m_data
# Out:
#         longitude   latitude  ... xco2_accuracy  contributing_algorithms
# 0     -162.774109  67.429771  ...      0.407804                        6
# 1     -162.775452  67.430260  ...      0.407804                        6
# 2     -162.778152  67.429016  ...      0.407804                        6
# 3     -157.362122  66.286560  ...      0.504706                        6
# 4     -157.364090  66.284111  ...      0.504706                        6
# ...           ...        ...  ...           ...                      ...
# 28485 -147.674637   5.661206  ...      0.407804                        5
# 28486 -147.675644   5.664542  ...      0.407804                        5
# 28487 -154.329590  65.727356  ...      0.504706                        6
# 28488 -154.328979  65.728973  ...      0.504706                        6
# 28489 -154.327744  65.729889  ...      0.504706                        6
#
# [28490 rows x 18 columns]

# %%
my_nc_file = '/content/drive/MyDrive/data/test/methane.nc'
ds = xr.open_mfdataset(my_nc_file)
m_data = ds.to_dataframe().reset_index(drop=True)
m_data = m_data[["time","xch4"]]
m_data['time'] = m_data['time'].dt.date
m_data_mean = m_data.groupby("time").mean()
m_data_mean.to_csv("/content/drive/MyDrive/data/methane.csv")
